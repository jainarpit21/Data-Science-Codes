# %%
# !pip install requests

# %%
import requests
res = requests.get('https://www.geeksforgeeks.org')

# %%
res
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(res.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
str(soup)
# Out:
# '<!DOCTYPE html>\n<html lang="en-us" prefix="og: http://ogp.me/ns#"><meta charset="utf-8"/><meta content="width=device-width,initial-scale=1,maximum-scale=1" name="viewport"/><meta content="A Computer Science portal for geeks. It contains well written, well thought and well explained computer science and programming articles, quizzes and practice/competitive programming/company interview Questions." name="description" property="og:description"/><meta content="https://www.geeksforgeeks.org/" property="og:url"/><link href="https://media.geeksforgeeks.org/wp-content/cdn-uploads/gfg_favicon.png" rel="shortcut icon" type="image/x-icon"/><meta content="#308D46" name="theme-color"/><meta content="https://media.geeksforgeeks.org/wp-content/cdn-uploads/gfg_200x200-min.png" name="image" property="og:image"/><meta content="image/png" property="og:image:type"/><meta content="200" property="og:image:width"/><meta content="200" property="og:image:height"/><script defer="" src="https://apis.google.
# ...

# %%
str(soup).split('<a')
# Out:
# ['<!DOCTYPE html>\n<html lang="en-us" prefix="og: http://ogp.me/ns#"><meta charset="utf-8"/><meta content="width=device-width,initial-scale=1,maximum-scale=1" name="viewport"/><meta content="A Computer Science portal for geeks. It contains well written, well thought and well explained computer science and programming articles, quizzes and practice/competitive programming/company interview Questions." name="description" property="og:description"/><meta content="https://www.geeksforgeeks.org/" property="og:url"/><link href="https://media.geeksforgeeks.org/wp-content/cdn-uploads/gfg_favicon.png" rel="shortcut icon" type="image/x-icon"/><meta content="#308D46" name="theme-color"/><meta content="https://media.geeksforgeeks.org/wp-content/cdn-uploads/gfg_200x200-min.png" name="image" property="og:image"/><meta content="image/png" property="og:image:type"/><meta content="200" property="og:image:width"/><meta content="200" property="og:image:height"/><script defer="" src="https://apis.google
# ...

# %%
len(str(soup).split('<a'))
# Out:
# 400

# %%
str(soup).split('<a')[1]
# Out:
# ' href="https://practice.geeksforgeeks.org/explore?page=1&sortBy=submissions&utm_source=practice&utm_medium=IDE&utm_campaign=practice-IDE">Improve your Coding Skills with Practice</a>\'; \r\n    var link_search_modal_top = \''

# %%
str(soup).split('<a')[3]
# Out:
# ' class="gfg-stc" href="#main" style="top:0">Skip to content</a>\n'

# %%
str(soup).split('<a')[3].split('</a>')[0]
# Out:
# ' class="gfg-stc" href="#main" style="top:0">Skip to content'

# %%
str(soup).split('<a')[3].split('</a>')[0]
# Out:
# ' class="gfg-stc" href="#main" style="top:0">Skip to content'

# %%
str(soup).split('<a')[3].split('</a>')[0].split('href="')
# Out:
# [' class="gfg-stc" ', '#main" style="top:0">Skip to content']

# %%
str(soup).split('<a')[3].split('</a>')[0].split('href="')[1]
# Out:
# '#main" style="top:0">Skip to content'

# %%
str(soup).split('<a')[3].split('</a>')[0].split('href="')[1].split('"')
# Out:
# ['#main', ' style=', 'top:0', '>Skip to content']

# %%
str(soup).split('<a')[3].split('</a>')[0].split('href="')[1].split('"')[0]
# Out:
# '#main'

# %%
links = []

for i in str(soup).split('<a'):
    if ('href' in i):
        links.append(str(i).split('</a>')[0].split('href="')[1].split('"')[0])

# %%
links
# Out:
# ['https://media.geeksforgeeks.org/wp-content/cdn-uploads/gfg_favicon.png',
#  'https://practice.geeksforgeeks.org/explore?page=1&sortBy=submissions&utm_source=practice&utm_medium=IDE&utm_campaign=practice-IDE',
#  'https://practice.geeksforgeeks.org/explore?page=1&sortBy=submissions&utm_source=gfg&utm_medium=search-bar&utm_campaign=practice-search',
#  '#main',
#  'https://www.geeksforgeeks.org/',
#  'https://practice.geeksforgeeks.org/courses/geeks-classes-live?utm_source=gfg&amp;utm_medium=Submenu&amp;utm_campaign=courses-submenu',
#  'https://practice.geeksforgeeks.org/courses/system-design-live?utm_source=gfg&amp;utm_medium=Submenu&amp;utm_campaign=courses-submenu',
#  'https://practice.geeksforgeeks.org/courses/java-backend-live?utm_source=gfg&amp;utm_medium=Submenu&amp;utm_campaign=courses-submenu',
#  'https://practice.geeksforgeeks.org/courses/full-stack-node?utm_source=gfg&amp;utm_medium=Submenu&amp;utm_campaign=courses-submenu',
# ...

# %%
fd = open('links.txt','a')

for link in links:
    fd.write(link + '\n')
    
fd.close()
